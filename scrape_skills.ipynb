# %%
# %pip install selenium
# Out:
# Requirement already satisfied: selenium in ./.networkx-venv/lib/python3.12/site-packages (4.46.0)
# Requirement already satisfied: certifi>=2026.2.25 in ./.networkx-venv/lib/python3.12/site-packages (from selenium) (2026.6.17)
# Requirement already satisfied: trio<1.0,>=0.31.0 in ./.networkx-venv/lib/python3.12/site-packages (from selenium) (0.33.0)
# Requirement already satisfied: trio-websocket<1.0,>=0.12.2 in ./.networkx-venv/lib/python3.12/site-packages (from selenium) (0.12.2)
# Requirement already satisfied: typing_extensions<5.0,>=4.15.0 in ./.networkx-venv/lib/python3.12/site-packages (from selenium) (4.16.0)
# Requirement already satisfied: urllib3<3.0,>=2.6.3 in ./.networkx-venv/lib/python3.12/site-packages (from urllib3[socks]<3.0,>=2.6.3->selenium) (2.7.0)
# Requirement already satisfied: websocket-client<2.0,>=1.8.0 in ./.networkx-venv/lib/python3.12/site-packages (from selenium) (1.9.0)
# Requirement already satisfied: attrs>=23.2.0 in ./.networkx-venv/lib/python3.12/site-packages (from trio<1.0,>=0.31.0->selenium) (26.1.0)
# Requirement already satisfied: sortedcontainers in ./.networkx-venv/lib/python3.12/site-packages (from trio<1.0,>=0.31.0->selenium) (2.4.0)
# Requirement already satisfied: idna in ./.networkx-venv/lib/python3.12/site-packages (from trio<1.0,>=0.31.0->selenium) (3.18)
# Requirement already satisfied: outcome in ./.networkx-venv/lib/python3.12/site-packages (from trio<1.0,>=0.31.0->selenium) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in ./.networkx-venv/lib/python3.12/site-packages (from trio<1.0,>=0.31.0->selenium) (1.3.1)
# Requirement already satisfied: wsproto>=0.14 in ./.networkx-venv/lib/python3.12/site-packages (from trio-websocket<1.0,>=0.12.2->selenium) (1.3.2)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in ./.networkx-venv/lib/python3.12/site-packages (from urllib3[socks]<3.0,>=2.6.3->selenium) (1.7.1)
# Requirement already satisfied: h11<1,>=0.16.0 in ./.networkx-venv/lib/python3.12/site-packages (from wsproto>=0.14->trio-websocket<1.0,>=0.12.2->selenium) (0.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from selenium import webdriver

# %%
# path of the chrome driver file
PATH = "/home/maxmin2127/Documents/projects/data-science-network-analysis/chromedriver.exe"

# %%
try: 
    driver = webdriver.Chrome(PATH)
    driver.get("https://techwithtim.net")

except Exception as e:
    print(e)
# Out:
# 'str' object has no attribute 'capabilities'
